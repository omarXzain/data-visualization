# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
planets = sns.load_dataset('planets')
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
info = planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
sns.relplot(x='mass', y='distance', data=planets)

# %%
sns.barplot(x='mass', y='distance', data=planets)
# Out:
# <AxesSubplot:xlabel='mass', ylabel='distance'>

# %%
planets = planets.groupby('orbital_period',as_index=False).sum()
planets
# Out:
#    orbital_period  number        mass   distance     year
# 0    8.345253e+02       7     0.00000    5460.00    14091
# 1    4.090624e+03       6     0.69400    4032.12    48254
# 2    5.994579e+03       5     4.66700    4867.65    60322
# 3    4.165718e+04       3    47.67735    8309.82   176831
# 4    1.621473e+05       2   265.31610   40715.28   520627
# 5    3.060638e+05       4    12.82440     318.64    64245
# 6    1.466106e+06       1  1022.19753  149664.47  1195018

# %%
sns.barplot(x='distance',y='mass',data=planets)
# Out:
# <AxesSubplot:xlabel='distance', ylabel='mass'>
